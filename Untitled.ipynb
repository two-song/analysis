# %%
import requests
import json

url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=c07f10c0c6be85331f51b83f7aa54e9a&targetDt=20230101'
#url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=130ad25d8935a673ca47beb43436aa85&targetDt=20180220'
res = requests.get(url)
text = res.text
#print(text)

d = json.loads(text) 
#print(d)

# %%
d
# Out:
# {'boxOfficeResult': {'boxofficeType': '일별 박스오피스',
#   'showRange': '20230101~20230101',
#   'dailyBoxOfficeList': [{'rnum': '1',
#     'rank': '1',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20225061',
#     'movieNm': '아바타: 물의 길',
#     'openDt': '2022-12-14',
#     'salesAmt': '5546745851',
#     'salesShare': '63.2',
#     'salesInten': '-1027346873',
#     'salesChange': '-15.6',
#     'salesAcc': '95843585053',
#     'audiCnt': '429533',
#     'audiInten': '-85748',
#     'audiChange': '-16.6',
#     'audiAcc': '7742682',
#     'scrnCnt': '2047',
#     'showCnt': '7148'},
#    {'rnum': '2',
#     'rank': '2',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20196478',
#     'movieNm': '영웅',
#     'openDt': '2022-12-21',
#     'salesAmt': '1908571119',
#     'salesShare': '21.7',
#     'salesInten': '-173788777',
#     'salesChange': '-8.3',
#     'salesAcc': '16442796442',
#     'audiCnt': '185254',
# ...

# %%
for b in d['boxOfficeResult']['여기에 코드를 작성하세요']:
    print(b['rank'], b['여기에 코드를 작성하세요'], b['여기에 코드를 작성하세요'], b['여기에 코드를 작성하세요'], b['여기에 코드를 작성하세요'], b['여기에 코드를 작성하세요'])

# %%
# %pip install xlrd
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 6.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

pd.read_excel('KOBIS_총_관객수_및_매출액_연도별_2024-03-15.xls', engine='xlrd')
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 import pandas as pd
# ----> 3 pd.read_excel('KOBIS_총_관객수_및_매출액_연도별_2024-03-15.xls', engine='xlrd')
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/io/excel/_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
# ...
