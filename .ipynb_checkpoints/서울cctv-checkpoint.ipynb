# %%
import pandas as pd
import numpy as np

# %%
# 데이터 불러오기

# %%
cctv = pd.read_csv('서울cctv.csv')

# %%
pop = pd.read_csv('서울인구.csv')

# %%
crime = pd.read_csv('서울범죄.csv',encoding='utf-8')

# %%
cctv.head()
# Out:
#    자치구                                안심 주소       위도        경도  CCTV 수량  \
# 0  중랑구  중화2동 326-86 (주택가 골목삼거리)_C-JH02-0032  37.5977  127.0728        1
# 1  중랑구        면목2동 146-1(고정3)_C-MM02-0013-C  37.5879  127.0812        1
# 2  중랑구  중화2동 326-88 (골목길 통신주)_C-JH02-0032-1  37.5976  127.0727        1
# 3  중랑구        면목2동 146-1(고정2)_C-MM02-0013-B  37.5879  127.0812        1
# 4  중랑구       중화2동 327-27 (고정)_C-JH02-0044-A  37.5986  127.0747        1
#
#         수정 일시
# 0  2022-12-01
# 1  2022-12-01
# 2  2022-12-01
# 3  2022-12-01
# 4  2022-12-01

# %%
pop.head()
# Out:
#          시점   구분별(1) 구분별(2) 동별(1) 동별(2)     데이터
# 0  2023 3/4  한국인 (명)     남자    합계   종로구   67625
# 1  2023 3/4  한국인 (명)     남자    합계    중구   58788
# 2  2023 3/4  한국인 (명)     남자    합계   용산구  103804
# 3  2023 3/4  한국인 (명)     남자    합계   성동구  135143
# 4  2023 3/4  한국인 (명)     남자    합계   광진구  161892

# %%
pop.rename(columns = {'동별(2)':'자치구', '구분별(1)':'국적', '구분별(2)':'성별', '데이터':'인구수'}, inplace=True)

# %%
crime.head()
# Out:
#    구분     죄종 발생검거   건수
# 0  중부     살인   발생    4
# 1  중부     살인   검거    4
# 2  중부     강도   발생    3
# 3  중부     강도   검거    3
# 4  중부  강간,추행   발생  109

# %%
# 필요없는 컬럼 삭제

cctv.drop(columns = ['수정 일시'], inplace=True)
pop.drop(columns = ['시점'], inplace=True)

# %%
pop['동별(1)'].unique()
# Out:
# array(['합계'], dtype=object)

# %%
pop.drop(columns = ['동별(1)'], inplace=True)

# %%
cctv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83734 entries, 0 to 83733
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   자치구      83734 non-null  object
#  1   안심 주소    83734 non-null  object
#  2   위도       83734 non-null  float64
#  3   경도       83734 non-null  float64
#  4   CCTV 수량  83734 non-null  int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 3.2+ MB

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국적      100 non-null    object
#  1   성별      100 non-null    object
#  2   자치구     100 non-null    object
#  3   인구수     100 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 3.3+ KB

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   구분      310 non-null    object
#  1   죄종      310 non-null    object
#  2   발생검거    310 non-null    object
#  3   건수      310 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 9.8+ KB

# %%
crime['구분'].unique()
# Out:
# array(['중부', '종로', '남대문', '서대문', '혜화', '용산', '성북', '동대문', '마포', '영등포',
#        '성동', '동작', '광진', '서부', '강북', '금천', '중랑', '강남', '관악', '강서', '강동',
#        '종암', '구로', '서초', '양천', '송파', '노원', '방배', '은평', '도봉', '수서'],
#       dtype=object)

# %%
crime.rename(columns={'구분':'관서'}, inplace=True)

# %%
# crime 데이터에 주소 추가를 위한 경찰서 정보 데이터 불러오기

pol = pd.read_csv('서울경찰서.csv')

# %%
pol.head()
# Out:
#         관서                    주소
# 0  서울강남경찰서  서울시 강남구 테헤란로 114길 11
# 1  서울강동경찰서        서울시 강동구 성내로 57
# 2  서울강북경찰서      서울시 강북구 오패산로 406
# 3  서울강서경찰서       서울시 강서구 화곡로 308
# 4  서울관악경찰서      서울시 관악구 관악로5길 33

# %%
# 관서명 변경

# %%
pol['관서'] = pol['관서'].str.replace('서울', '')
pol['관서'] = pol['관서'].str.replace('경찰서', '')

pol
# Out:
#      관서                    주소
# 0    강남  서울시 강남구 테헤란로 114길 11
# 1    강동        서울시 강동구 성내로 57
# 2    강북      서울시 강북구 오패산로 406
# 3    강서       서울시 강서구 화곡로 308
# 4    관악      서울시 관악구 관악로5길 33
# 5    광진       서울시 광진구 자양로 167
# 6    구로      서울시 구로구 가마산로 235
# 7    금천    서울시 금천구 시흥대로73길 50
# 8   남대문       서울시 중구 한강대로 410
# 9    노원       서울시 노원구 노원로 283
# 10   도봉       서울시 도봉구 노해로 403
# 11  동대문   서울시 동대문구 약령시로21길 29
# 12   동작      서울시 동작구 노량진로 148
# 13   마포      서울시 마포구 마포대로 183
# 14   방배      서울시 서초구 동작대로 204
# 15  서대문       서울 서대문구 통일로 113
# 16   서부        서울시 은평구 진흥로 58
# 17   서초      서울시 서초구 반포대로 179
# 18   성동      서울시 성동구 왕십리광장로 9
# 19   성북        서울 성북구 보문로 170
# 20   송파       서울시 송파구 중대로 221
# 21   수서       서울시 강남구 개포로 617
# 22   양천       서울시 양천구 목동동로 99
# 23  영등포     서울시 영등포구 국회대로 608
# 24   용산     서울시 용산구 원효로89길 24
# 25   은평       서울시 은평구 연서로 365
# 26   종로        서울시 종로구 율곡로 46
# 27   종암       서울시 성북구 종암로 135
# 28   중랑  서울시 중랑구 신내역로3길 40-10
# 29   중부         서울시 중구 수표로 27
# 30   혜화   서울시 종로구 창경궁로 112-16

# %%
# 자치구 컬럼 만들기

# %%
pol['자치구'] = pol['주소'].str.split(' ').str[1]

# %%
pol.drop(columns = ['주소'], inplace=True)

# %%
# crime 데이터와 합치기

# %%
crime = pd.merge(crime, pol, on = '관서')

# %%
crime
# Out:
#      관서     죄종 발생검거    건수  자치구
# 0    중부     살인   발생     4   중구
# 1    중부     살인   검거     4   중구
# 2    중부     강도   발생     3   중구
# 3    중부     강도   검거     3   중구
# 4    중부  강간,추행   발생   109   중구
# ..   ..    ...  ...   ...  ...
# 305  수서  강간,추행   검거   129  강남구
# 306  수서     절도   발생   855  강남구
# 307  수서     절도   검거   423  강남구
# 308  수서     폭력   발생  1198  강남구
# 309  수서     폭력   검거  1050  강남구
#
# [310 rows x 5 columns]

# %%
# pivot하여 데이터 정리
crime.drop(columns = ['관서'], inplace=True)

crime = crime.pivot_table(crime, index=['자치구'],
                          columns=['죄종', '발생검거'],
                          aggfunc=[np.sum])
crime
# Out:
#        sum                                                               \
#         건수
# 동작구   1056.0  1319.0
# 마포구   1367.0  1701.0
# 서대문구   907.0  1109.0
# 서초구   1506.0  1827.0
# 성동구    926.0  1090.0
# 성북구   1220.0  1392.0
# 송파구   2046.0  2433.0
# 양천구   1289.0  1546.0
# 영등포구  1731.0  2169.0
# 용산구   1069.0  1291.0
# 은평구   1457.0  1647.0
# 종로구   1188.0  1467.0
# 중구    1224.0  1409.0
# 중랑구   1442.0  1660.0

# %%
crime = crime.fillna(0)
crime.isnull().sum()
# Out:
#          죄종     발생검거
# sum  건수  강간     검거      0
#                 발생      0
#          강간,추행  검거      0
#                 발생      0
#          강도     검거      0
#                 발생      0
#          살인     검거      0
#                 발생      0
#          절도     검거      0
#                 발생      0
#          폭력     검거      0
#                 발생      0
# dtype: int64

# %%
crime.columns = crime.columns.droplevel([0, 1])
crime.head()
# Out:
# 죄종     강간       강간,추행           강도          살인            절도              폭력  \
# 발생검거   검거   발생     검거     발생    검거    발생    검거    발생      검거      발생      검거
# 자치구
# 강남구   0.0  0.0  454.0  578.0  23.0  25.0  11.0  12.0  1160.0  2372.0  2749.0
# 강동구   0.0  0.0  103.0  124.0   6.0   6.0   3.0   3.0   889.0  1612.0  1461.0
# 강북구   0.0  0.0  115.0  136.0   1.0   1.0   4.0   4.0   537.0   777.0  1255.0
# 강서구   0.0  0.0  188.0  246.0   3.0   3.0   7.0   9.0   921.0  1540.0  1925.0
# 관악구   0.0  0.0  269.0  321.0   6.0   7.0   4.0   8.0   929.0  1860.0  1926.0
#
# 죄종
# 발생검거      발생
# 자치구
# 강남구   3159.0
# 강동구   1713.0
# 강북구   1383.0
# 강서구   2098.0
# 관악구   2248.0

# %%
# 레벨0, 레벨1의 컬럼명을 합쳐 컬럼명 변경
tmp = [
    crime.columns.get_level_values(0)[n] + " "
    + crime.columns.get_level_values(1)[n]
    for n in range(0, len(crime.columns.get_level_values(0)))
]
crime.columns = tmp
crime.head()
# Out:
#      강간 검거  강간 발생  강간,추행 검거  강간,추행 발생  강도 검거  강도 발생  살인 검거  살인 발생   절도 검거  \
# 자치구
# 강남구    0.0    0.0     454.0     578.0   23.0   25.0   11.0   12.0  1160.0
# 강동구    0.0    0.0     103.0     124.0    6.0    6.0    3.0    3.0   889.0
# 강북구    0.0    0.0     115.0     136.0    1.0    1.0    4.0    4.0   537.0
# 강서구    0.0    0.0     188.0     246.0    3.0    3.0    7.0    9.0   921.0
# 관악구    0.0    0.0     269.0     321.0    6.0    7.0    4.0    8.0   929.0
#
#       절도 발생   폭력 검거   폭력 발생
# 자치구
# 강남구  2372.0  2749.0  3159.0
# 강동구  1612.0  1461.0  1713.0
# 강북구   777.0  1255.0  1383.0
# 강서구  1540.0  1925.0  2098.0
# 관악구  1860.0  1926.0  2248.0

# %%
target = ["강간 검거율", "강간,추행 검거율", "강도 검거율", "살인 검거율", "절도 검거율", "폭력 검거율"]
num = ["강간 검거", "강간,추행 검거", "강도 검거", "살인 검거", "절도 검거", "폭력 검거"]
den = ["강간 발생", "강간,추행 발생", "강도 발생", "살인 발생", "절도 발생", "폭력 발생"]

crime[target] = crime[num].div(crime[den].values) * 100
crime.head()
# Out:
#      강간 검거  강간 발생  강간,추행 검거  강간,추행 발생  강도 검거  강도 발생  살인 검거  살인 발생   절도 검거  \
# 자치구
# 강남구    0.0    0.0     454.0     578.0   23.0   25.0   11.0   12.0  1160.0
# 강동구    0.0    0.0     103.0     124.0    6.0    6.0    3.0    3.0   889.0
# 강북구    0.0    0.0     115.0     136.0    1.0    1.0    4.0    4.0   537.0
# 강서구    0.0    0.0     188.0     246.0    3.0    3.0    7.0    9.0   921.0
# 관악구    0.0    0.0     269.0     321.0    6.0    7.0    4.0    8.0   929.0
#
#       절도 발생   폭력 검거   폭력 발생  강간 검거율  강간,추행 검거율      강도 검거율      살인 검거율  \
# 자치구
# 강남구  2372.0  2749.0  3159.0     NaN  78.546713   92.000000   91.666667
# 강동구  1612.0  1461.0  1713.0     NaN  83.064516  100.000000  100.000000
# 강북구   777.0  1255.0  1383.0     NaN  84.558824  100.000000  100.000000
# 강서구  1540.0  1925.0  2098.0     NaN  76.422764  100.000000   77.777778
# 관악구  1860.0  1926.0  2248.0     NaN  83.800623   85.714286   50.000000
#
#         절도 검거율     폭력 검거율
# 자치구
# 강남구  48.903879  87.021209
# 강동구  55.148883  85.288967
# 강북구  69.111969  90.744758
# 강서구  59.805195  91.754051
# 관악구  49.946237  85.676157

# %%
crime.drop(columns = ["강간 검거", "강간,추행 검거", "강도 검거", "살인 검거", "절도 검거", "폭력 검거"], inplace=True)

# %%
crime.rename(
    columns={"강간 발생" : "강간", "강간,추행 발생" : "강간,추행", "강도 발생" : "강도", "살인 발생" : "살인", "절도 발생" : "절도", "폭력 발생" : "폭력"},
    inplace=True
)

# %%
crime
# Out:
#          강간  강간,추행    강도    살인      절도      폭력     강간 검거율  강간,추행 검거율  \
# 자치구
# 강남구     0.0  578.0  25.0  12.0  2372.0  3159.0        NaN  78.546713
# 강동구     0.0  124.0   6.0   3.0  1612.0  1713.0        NaN  83.064516
# 강북구     0.0  136.0   1.0   4.0   777.0  1383.0        NaN  84.558824
# 강서구     0.0  246.0   3.0   9.0  1540.0  2098.0        NaN  76.422764
# 관악구     0.0  321.0   7.0   8.0  1860.0  2248.0        NaN  83.800623
# 광진구     0.0  208.0   4.0   5.0  1414.0  1456.0        NaN  77.403846
# 구로구     0.0  182.0   2.0   5.0  1390.0  1907.0        NaN  64.835165
# 금천구     0.0  134.0   3.0   7.0  1013.0  1282.0        NaN  76.865672
# 노원구     0.0  156.0   3.0   6.0  1361.0  1899.0        NaN  80.769231
# 도봉구    72.0    0.0   2.0   2.0   772.0  1012.0  88.888889        NaN
# 동대문구    0.0  169.0   7.0   3.0  1240.0  1540.0        NaN  86.982249
# 3      중랑구        면목2동 146-1(고정2)_C-MM02-0013-B  37.5879  127.0812        1
# 4      중랑구       중화2동 327-27 (고정)_C-JH02-0044-A  37.5986  127.0747        1
# ...    ...                                  ...      ...       ...      ...
# 83729  강남구                           대치2-256-02  37.5059  127.0589        1
# 83730  강남구                            수서-208-01  37.4902  127.1014        1
# 83731  강남구                            수서-208-02  37.4902  127.1014        1
# 83732  강남구                           대치2-256-03  37.5059  127.0589        1
# 83733  강남구                            수서-208-03  37.4902  127.1014        1
#
# [83734 rows x 5 columns]

# %%
cctv = cctv.groupby('자치구').sum()

# %%
cctv.drop(columns = ["안심 주소", "위도", "경도"], inplace=True)

# %%
cctv
# Out:
#       CCTV 수량
# 자치구
# 강남구      7009
# 강동구      3191
# 강북구      2858
# 강서구      3481
# 관악구      5366
# 광진구      4091
# 구로구      4050
# 금천구      2725
# 노원구      2655
# 도봉구      1598
# 동대문구     2857
# 동작구      2650
# 마포구      2450
# 서대문구     3224
# 서초구      5060
# 성동구      4036
# 성북구      3943
# 송파구      3094
# 양천구      3845
# 영등포구     2899
# 용산구      1078
# 은평구      4116
# 종로구      1930
# 중구       2336
# 중랑구      3471

# %%
pop = pop.groupby('자치구').sum()
pop.drop(columns = ["국적", "성별"], inplace=True)
pop
# Out:
#          인구수
# 자치구
# 강남구   546291
# 강동구   462453
# 강북구   294804
# 강서구   569978
# 관악구   500582
# 광진구   351959
# 구로구   416815
# 금천구   242076
# 노원구   504423
# 도봉구   310133
# 동대문구  359113
# 동작구   390740
# 마포구   375639
# 서대문구  321379
# 서초구   410766
# 성동구   285543
# 성북구   440089
# 송파구   661515
# 양천구   440591
# 영등포구  398290
# 용산구   230692
# 은평구   471155
# 종로구   151127
# 중구    131825
# 중랑구   387940

# %%
seoul = pd.merge(cctv, pop, on='자치구')

# %%
seoul
# Out:
#       CCTV 수량     인구수
# 자치구
# 강남구      7009  546291
# 강동구      3191  462453
# 강북구      2858  294804
# 강서구      3481  569978
# 관악구      5366  500582
# 광진구      4091  351959
# 구로구      4050  416815
# 금천구      2725  242076
# 노원구      2655  504423
# 도봉구      1598  310133
# 동대문구     2857  359113
# 동작구      2650  390740
# 마포구      2450  375639
# 서대문구     3224  321379
# 서초구      5060  410766
# 성동구      4036  285543
# 성북구      3943  440089
# 송파구      3094  661515
# 양천구      3845  440591
# 영등포구     2899  398290
# 용산구      1078  230692
# 은평구      4116  471155
# 종로구      1930  151127
# 중구       2336  131825
# 중랑구      3471  387940

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
import matplotlib.pyplot as plt

fp1 = np.polyfit(seoul['인구수'], seoul['CCTV 수량'], 1)

f1 = np.poly1d(fp1)
fx = np.linspace(100000, 700000, 100)

plt.figure(figsize=(14, 10))
plt.scatter(seoul['인구수'], seoul['CCTV 수량'], s=50)
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='g')
plt.xlabel('인구수')
plt.ylabel('CCTV 수량')
for n in range(25):
    plt.text(seoul['인구수'][n], seoul['CCTV 수량'][n], seoul.index[n], fontsize=10)
plt.grid()
plt.show()
